# %%
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time
import re

from tqdm import tqdm

# %%
df = pd.read_csv('nowon.csv')
print(len(df))
df.tail()
# Out:
# 4251
#         상호명 상권업종대분류명      표준산업분류명 시군구명 법정동명                   도로명주소  \
# 4246   범피버거       음식   그외 기타 음식점업  노원구  공릉동     서울특별시 노원구 공릉로41길 12
# 4247     휴랩       음식  분식 및 김밥 전문점  노원구  공릉동  서울특별시 노원구 동일로173가길 140
# 4248     식껍       음식      한식 음식점업  노원구  중계동   서울특별시 노원구 한글비석로20길 38
# 4249  기찻길풍경       음식      한식 음식점업  노원구  공릉동     서울특별시 노원구 공릉로39길 21
# 4250  더쌍화커피       음식     비알콜 음료점업  노원구  중계동     서울특별시 노원구 덕릉로83길 16
#
#              위도          경도        검색어              역 명          거리
# 4246  37.624607  127.078926   공릉동 범피버거  7호선 공릉(서울과학기술대)  553.934421
# 4247  37.624445  127.071984     공릉동 휴랩  7호선 공릉(서울과학기술대)  174.699226
# 4248  37.660793  127.074274     중계동 식껍           4호선 상계   74.014219
# 4249  37.623620  127.078259  공릉동 기찻길풍경  7호선 공릉(서울과학기술대)  538.488045
# 4250  37.660092  127.074544  중계동 더쌍화커피           4호선 상계  143.117174

# %%
df['naver_keyword'] = df['법정동명'] + "%20" + df['상호명']
df['naver_map_url'] = ''

# %%
driver = webdriver.Chrome(executable_path=r'C:\Users\jennie\Desktop\BOAZ\chromedriver_win32\chromedriver.exe')

# %%
for i, keyword in enumerate(df['naver_keyword'].tolist()):
    print("이번에 찾을 키워드 :", i, f"/ {df.shape[0]} 행", keyword)
    
    try:
        naver_map_search_url = f'https://map.naver.com/v5/search/{keyword}/place'
        driver.get(naver_map_search_url)
        
        time.sleep(4)
        cu = driver.current_url
        
        res_code = re.findall(r"place/(\d+)", cu)
        final_url = 'https://pcmap.place.naver.com/restaurant/'+res_code[0]+'/review/visitor#'
        
        print(final_url)
        df['naver_map_url'][i]=final_url
    
    
    except IndexError:
        df['naver_map_url'][i]=''
        print('none')

# %%
df.tail()
# Out:
#         상호명 상권업종대분류명      표준산업분류명 시군구명 법정동명                   도로명주소  \
# 4246   범피버거       음식   그외 기타 음식점업  노원구  공릉동     서울특별시 노원구 공릉로41길 12
# 4247     휴랩       음식  분식 및 김밥 전문점  노원구  공릉동  서울특별시 노원구 동일로173가길 140
# 4248     식껍       음식      한식 음식점업  노원구  중계동   서울특별시 노원구 한글비석로20길 38
# 4249  기찻길풍경       음식      한식 음식점업  노원구  공릉동     서울특별시 노원구 공릉로39길 21
# 4250  더쌍화커피       음식     비알콜 음료점업  노원구  중계동     서울특별시 노원구 덕릉로83길 16
#
#              위도          경도        검색어              역 명          거리  \
# 4246  37.624607  127.078926   공릉동 범피버거  7호선 공릉(서울과학기술대)  553.934421
# 4247  37.624445  127.071984     공릉동 휴랩  7호선 공릉(서울과학기술대)  174.699226
# 4248  37.660793  127.074274     중계동 식껍           4호선 상계   74.014219
# 4249  37.623620  127.078259  공릉동 기찻길풍경  7호선 공릉(서울과학기술대)  538.488045
# 4250  37.660092  127.074544  중계동 더쌍화커피           4호선 상계  143.117174
#
#      naver_keyword                                      naver_map_url
# 4246    공릉동%20범피버거  https://pcmap.place.naver.com/restaurant/18175...
# 4247      공릉동%20휴랩
# 4248      중계동%20식껍  https://pcmap.place.naver.com/restaurant/15039...
# 4249   공릉동%20기찻길풍경  https://pcmap.place.naver.com/restaurant/13249...
# 4250   중계동%20더쌍화커피

# %%
df.to_csv('노원_1차크롤링sig.csv', encoding = 'utf-8-sig')

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
from selenium.webdriver.common.keys import Keys
import pandas as pd
import math
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# %%
data = pd.read_csv("Final Res.csv")
data = data[["상호명","상권업종중분류명","상권업종소분류명","도로명주소","역명","거리"]]
data["역"] = data["역명"].apply(lambda x : x.split(" ")[1])
data["역"] = data["역"].apply(lambda x : x.split("(")[0])
data["검색어"] = data.apply(lambda x : x["역"] + "역 " + str(x["상호명"]),axis=1)
data
# Out:
#               상호명 상권업종중분류명   상권업종소분류명                 도로명주소  \
# 0       도전최강달인왕만두       한식  한식/백반/한정식     서울특별시 강동구 고덕로 333
# 1              이때       한식  한식/백반/한정식   서울특별시 마포구 동교로38안길 7
# 2           L.A.D       한식  한식/백반/한정식  서울특별시 마포구 잔다리로3안길 23
# 3         제이씨에스푸드       한식  한식/백반/한정식    서울특별시 관악구 신림로14길 3
# 4             비지트       한식  한식/백반/한정식   서울특별시 서초구 동광로18길 82
# ...           ...      ...        ...                   ...
# 135805       얼음과자    패스트푸드    아이스크림판매    서울특별시 강서구 금낭화로 135
# 135806      오이소서울    패스트푸드    아이스크림판매  서울특별시 강동구 고덕로80길 123
# 135807   얼음왕국명일14    패스트푸드    아이스크림판매     서울특별시 강동구 상암로 214
# 135808       얼음과자    패스트푸드    아이스크림판매    서울특별시 강동구 고덕로83길 6
# 135809       꽁꽁냠냠    패스트푸드    아이스크림판매  서울특별시 중랑구 용마산로96길 32
#
#                        역명           거리     역             검색어
# 0                 5호선 상일동   373.362877   상일동  상일동역 도전최강달인왕만두
# 1               경의중앙 홍대입구   360.468770  홍대입구        홍대입구역 이때
# 2                2호선 홍대입구   583.594176  홍대입구     홍대입구역 L.A.D
# 3                  2호선 봉천   860.540255    봉천     봉천역 제이씨에스푸드
# 4                  2호선 방배   810.975643    방배         방배역 비지트
# ...                   ...          ...   ...             ...
# 135805             5호선 방화    27.430119    방화        방화역 얼음과자
# 135806            5호선 상일동   983.009054   상일동      상일동역 오이소서울
# 135807  5호선 굽은다리(강동구민회관앞)   347.273163  굽은다리  굽은다리역 얼음왕국명일14
# 135808            5호선 상일동  1380.011573   상일동       상일동역 얼음과자
# 135809            경의중앙 망우  1089.680702    망우        망우역 꽁꽁냠냠
#
# [135810 rows x 8 columns]

# %%
items = data["검색어"].head(20)
items
# Out:
# 0     상일동역 도전최강달인왕만두
# 1           홍대입구역 이때
# 2        홍대입구역 L.A.D
# 3        봉천역 제이씨에스푸드
# 4            방배역 비지트
# 5        총신대입구역 쓰리에프
# 6             종각역 채움
# 7         선유도역 호구의주방
# 8             서초역 다향
# 9        압구정역 고향생막걸리
# 10      남부터미널역 든든한우家
# 11        신목동역 이삭토스트
# 12        아차산역 옥돌영양탕
# 13     몽촌토성역 양푼이김치찌개
# 14         애오개역 은진이네
# 15         오목교역 흥부보쌈
# 16         문정역 고수의족발
# 17     선정릉역 호랑이가만든족발
# 18      왕십리역 왕십리제일곱창
# 19           혜화역 커피빈
# Name: 검색어, dtype: object

# %%
rating_df = pd.DataFrame(columns = ["UserID","ItemID","Rating","Timestamp"])
user_review_id = {}
review_json = {}
image_json = {}

# %%
count=0
for item in items:
    driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
    searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
    searchbox.send_keys(item)
    searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
    driver.execute_script("arguments[0].click();", searchbutton)
    time.sleep(2)

# %%
driver = webdriver.Chrome(r'C:/Users/user/Desktop/dd/Data_Handling/chromedriver.exe')




count = 0
for item in items:
    # 리뷰가 없을 때의 코드
    
    driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
    searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
    searchbox.send_keys(item)
    searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
    driver.execute_script("arguments[0].click();", searchbutton)
    time.sleep(2)
    
    if len(driver.find_elements_by_xpath("//a[@class='moreview']")) != 0:
        print('식당 존재')
        driver.execute_script('window.open("about:blank", "_blank");') # 새 탭 열기
        reviewbutton = driver.find_element_by_xpath("//a[@class='numberofscore']")
        content_url = reviewbutton.get_attribute("href")    
        tabs = driver.window_handles
        driver.switch_to_window(tabs[1]) # 새 탭으로 이동
        driver.get(content_url) # 링크 열기
        time.sleep(3)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        review_lists = soup.select('.list_evaluation > li')
        print(len(review_lists))
        if len(review_lists) != 0 :
            for i, review in enumerate(review_lists) :
                user_review = review.select('.txt_comment > span') # 리뷰
                rating = review.select('.grade_star > em') # 별점
                img_url = review.select('.link_photo > img ') #이미지url
                user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                timestamp = review.select(' div > span.time_write') #시간정보
                print(user_review)
                print(rating)
                print(img_url)
                print(user_id)
                print(timestamp)
                row = {"UserID":user_review,"ItemID":item,"Rating":rating,"Timestamp":timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row,ignore_index=True)
                time.sleep(1)
        else :
            print("리뷰가 없습니다")
            
        try:
            for i in range(2,500):
                time.sleep(2)
                another_review = driver.find_element_by_xpath("//a[@data-page='" + str(i) + "']")
                another_review.click()
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                review_lists = soup.select('.list_evaluation > li')
                if len(review_lists) != 0 :
                    for i, review in enumerate(review_lists) :
                        user_review = review.select('.txt_comment > span') # 리뷰
                        rating = review.select('.grade_star > em') # 별점
                        img_url = review.select('.link_photo > img ') #이미지url
                        user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                        timestamp = review.select(' div > span.time_write') #시간정보
                        row = {"UserID":user_review,"ItemID":item,"Rating":rating,"Timestamp":timestamp}
                        row = pd.DataFrame(row, index=[i])
                        rating_df = rating_df.append(row,ignore_index=True)
                        time.sleep(1)
        except:
            print("더 이상 리뷰 존재 X")
        driver.switch_to_window(tabs[0])
        print("기본 페이지로 돌아가자")
            
    else:
        print("식당 존재 x")
# Out:
# 식당 존재 x
# 식당 존재
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: use driver.switch_to.window instead
# 5
# [<span>감사했습니다,</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/bgkXfY/btqy33qI8Xx/RtMVlh59sev2mcXP56w7TK/profile_640x640s.jpg" data-platform="kakaomap" data-userid="13gfkas" data-username="서지원" href="javascript:void(0);">서지원</a>]
# [<span class="time_write">2021.01.21.</span>]
# [<span>사장님 바뀜 ㅠㅠㅠㅠ</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="https://p.kakaocdn.net/th/talkp/wlZJQtZsda/KZ6vJIQtXkBFy4ntZluIH1/pv1d4x_640x640_s.jpg" data-platform="kakaomap" data-userid="ei79fa" data-username="Tuned by' SC" href="javascript:void(0);">Tuned by' SC</a>]
# [<span class="time_write">2020.11.29.</span>]
# [<span>일단 사람이 별로 없고!! "이때의 라떼"맛있음. 근데 양이 적어서 너무 아쉽 ㅜㅜㅜㅜㅜ맛잇어서 거의 두모금만에 다 마신듯.. 크로아상 짱 작은데 같이 주는 딸기크림이랑 먹으니까 맛있엇다!! 초코볼도 줌</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Fbf9484eb60e61d5cb6632c25ca9f16a6d1ab1f8c%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/44456557c7af9ccdb033446b44eec957a300b0b1?original" data-platform="kakaomap" data-userid="tqv4dr" data-username="벌꿀" href="javascript:void(0);">벌꿀</a>]
# [<span class="time_write">2020.09.14.</span>]
# [<span>보통이에요</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/3e2bf8645d8d19fc5aef8110a51ca0cc8a8a71f8?original" data-platform="kakaomap" data-userid="10m615r" data-username="🤍🤎🧡💜💙" href="javascript:void(0);">🤍🤎🧡💜💙</a>]
# [<span class="time_write">2020.08.21.</span>]
# [<span>친절하고 정성스럽게 만든 커피, 차메뉴가 다양하면 다 좋을 듯</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/0a1eeb2e2982f3f0a746796a78debf9f1711788e?original" data-platform="kakaomap" data-userid="v6a12s" data-username="52907" href="javascript:void(0);">52907</a>]
# [<span class="time_write">2020.08.07.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:70: DeprecationWarning: use driver.switch_to.window instead
# 식당 존재 x
# 식당 존재 x
# 식당 존재
# 1
# [<span>카프레제 샌드위치 시켜봤는데 충격적으로 맛있음...와....감동쓰ㅠㅠ</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="https://p.kakaocdn.net/th/talkp/wlW0QXOMcx/yJjMVSPt3ZLsNX9CKNaiK0/fumkyk_640x640_s.jpg" data-platform="kakaomap" data-userid="1fr1u37" data-username="Jungeun" href="javascript:void(0);">Jungeun</a>]
# [<span class="time_write">2021.01.23.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 5
# [<span>종로, 광화문 지역에서 제일 친절하고 진료 잘 하는 병원.</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2F3031e6fa6e9fe90234ffa0a70e3e72db4be069a90eae11d149973ead72e08c5f" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkoYg3qBAF/kwHBSQmDFDpO7YhjlH3150/3p7mgf.jpg" data-platform="kakaomap" data-userid="mvukb4" data-username="인원" href="javascript:void(0);">인원</a>]
# [<span class="time_write">2021.03.31.</span>]
# [<span>매우 꼼꼼하고 친절해요.</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2F397912fb3ec5e366000cd4c9359c47206212c3b1d65b1949cc04e32b2a605970" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/bWDnY8/btq02QXnONx/N8cBvzQioC9U3v1byFrsy1/img_640x640.jpg" data-platform="kakaomap" data-userid="1i0kqtk" data-username="초코송이" href="javascript:void(0);">초코송이</a>]
# [<span class="time_write">2021.03.29.</span>]
# [<span>LA에서 소문듣고 왔어요. 소개 받았을 때는 큰 기대 없었는데, 진료 받아보니까 너무 좋아요.</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2F629cae445432979293ce753bdde4d869a4493b4b34bb4748c1b5ff4f588d3d63" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/bLKVMG/btqQSBCLRPp/gz5TkAQHRm4KDh1irSHsK0/img_640x640.jpg" data-platform="kakaomap" data-userid="1hsd9q1" data-username="가을하늘" href="javascript:void(0);">가을하늘</a>]
# [<span class="time_write">2021.03.25.</span>]
# [<span>여기가 제일 좋아요. 타지에서 아프면 서러운데, 친절하게 봐주시니 마음까지 편안해져요.</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/cuDIKg/btqZfv1xTI0/eOBFaV5vuckYdEhTzxN4jK/img_640x640.jpg" data-platform="kakaomap" data-userid="1h52u2r" data-username="마이쮸" href="javascript:void(0);">마이쮸</a>]
# [<span class="time_write">2021.03.04.</span>]
# [<span>아팠던 곳이 알고보니 생각지 못했던게 원인이었네요. 만족스럽습니다.</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/nq6nb/btqNpvllu87/MuKiPh4MX1zCNJMVFOaQP1/img_640x640.jpg" data-platform="kakaomap" data-userid="1g6b7r9" data-username="프리윈디오카리나" href="javascript:void(0);">프리윈디오카리나</a>]
# [<span class="time_write">2021.02.03.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재 x
# 식당 존재
# 3
# [<span>정말 맛있네요~</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="https://p.kakaocdn.net/th/talkp/wkH3j1NC4h/Ak3EM40kRy0XEOS5mqsAnk/19h33c_640x640_s.jpg" data-platform="kakaomap" data-userid="1a7lf9b" data-username="최진환" href="javascript:void(0);">최진환</a>]
# [<span class="time_write">2021.02.22.</span>]
# [<span>그동안  먹어본  찰밥중 최고의  맛!  평소에  집에  두고 먹으면  좋은  찰밥.  특히 정월 보름에는 꼭  먹어야하는  찰밥.  재료도 좋고 솜씨도 최고!</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Ff3da3e1b7b31ac320b73f76a5b3958c18614017a1d89114585ad840b9b459669" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/bEcW7n/btqCFylgVnm/0ZIJufvsRJJrW9qlVXm140/img_640x640.jpg" data-platform="kakaomap" data-userid="17ab6t8" data-username="💖  유당  尹  💖" href="javascript:void(0);">💖  유당  尹  💖</a>]
# [<span class="time_write">2021.02.16.</span>]
# [<span>최고예요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkDX1qyQs5/YxgL3K2HjHczFaRdY1ewH0/t74fec.jpg" data-platform="kakaomap" data-userid="dfa4rd" data-username="순수지키미" href="javascript:void(0);">순수지키미</a>]
# [<span class="time_write">2021.01.21.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재 x
# 식당 존재
# 5
# [<span>육회비빔밥 좋아해서 자주갔는데 리모델링하고 나서  비싸져서 아쉬움</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="" data-platform="kakaomap" data-userid="efkvsh" data-username="ㄱㅅ" href="javascript:void(0);">ㄱㅅ</a>]
# [<span class="time_write">2020.09.08.</span>]
# [<span>밑어 조보연인가 지가 일찍가서 밥 못처먹었다고 별 한개 찍은거봐라ㅋ ○○○같은짓거리하네 그럴거면 니친정 어무이한테 이른점심 해달라해라</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkRU1QX1JV/zQhpG5jkRP88pWceUwBhjk/xkryux.jpg" data-platform="kakaomap" data-userid="riq427" data-username="☆" href="javascript:void(0);">☆</a>]
# [<span class="time_write">2020.07.25.</span>]
# [<span>찾아갔더니 영업시간이 11시반부터라고함. 직원들만 있는데 손님 못받는다고함. 직원출근시간이 10시 부터라고 하니 이른 점심 드실분들은 애써 찾아가지 마세요. </span>]
# [<em class="num_rate">1<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wk1QIgOS4r/3Ig69myPcXbN0fJd3HDZjK/h94u7g.jpg" data-platform="kakaomap" data-userid="uhb32c" data-username="ㄴㄴ" href="javascript:void(0);">ㄴㄴ</a>]
# [<span class="time_write">2019.02.11.</span>]
# [<span>맛 분위기 직원서비스 주차가능 등 고려시 강남지역에서는 최고입니다 얼마전에 동창회를 했는데 시끌벅적 했지만 별도 방을  줘서 다른사람 신경 쓰지않았고 차가 여러대 왔는대도 주차타워가 있어서 믄제가 되지 않았어요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkVWsRyDEd/eXHiDv6VMhiahQxECme5nk/2wkwdr.jpg" data-platform="kakaomap" data-userid="rtepaf" data-username="최조열" href="javascript:void(0);">최조열</a>]
# [<span class="time_write">2018.10.12.</span>]
# [<span>최고예요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/098c04bb5fd27ae3a71e39e8ad6ce9b1f540fa38?original" data-platform="kakaomap" data-userid="lo8gop" data-username="user" href="javascript:void(0);">user</a>]
# [<span class="time_write">2018.08.30.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 5
# [<span>보통이에요</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/msB6o/btqztyXE94Q/33cRbFrQ7LuSd0GHthBRnK/img_640x640.jpg" data-platform="kakaomap" data-userid="13urkcg" data-username="김현빈" href="javascript:void(0);">김현빈</a>]
# [<span class="time_write">2021.03.20.</span>]
# [<span>친절하고 깨끗</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/82dafcd6ffeb0a70acc3de99adca386c931468aa?original" data-platform="kakaomap" data-userid="13etdou" data-username="룩" href="javascript:void(0);">룩</a>]
# [<span class="time_write">2020.12.16.</span>]
# [<span>아침 대용으로 굿!</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# []
# []
# [<span class="time_write">2017.03.26.</span>]
# [<span>조금 아쉬워요</span>]
# [<em class="num_rate">2<span class="screen_out">점</span></em>]
# []
# []
# [<span class="time_write">2017.03.20.</span>]
# [<span>맛나요. 좋아요.</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# []
# [<span class="time_write">2017.01.15.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 1
# [<span>맛있어요  맛없으면 돼지가 되겠습니다 !</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/8b4cdec16832ab61451245b03a0854c4c7ea9eb4?original" data-platform="kakaomap" data-userid="12sbdhf" data-username="신이나" href="javascript:void(0);">신이나</a>]
# [<span class="time_write">2020.01.14.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재 x
# 식당 존재
# 4
# [<span>선한영향력가게</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkESgtojN1/e4o9RXQh9Rh9jR4aRQxHIK/zw1prk.jpg" data-platform="kakaomap" data-userid="7khi0j" data-username="203" href="javascript:void(0);">203</a>]
# [<span class="time_write">2021.03.17.</span>]
# [<span>족발이 적절하게 쫄깃하고 맛있네요. 평소엔 매운거 잘 안먹는 편인데 여기 불족발 만은 자꾸 생각나는 맛. 추천할만합니다. </span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/1c1608794a214e5e3a7bb701c2e0b2bbf7df54d74835810c9a7420275f99233a" data-platform="kakaomap" data-userid="bergcg" data-username="한성주" href="javascript:void(0);">한성주</a>]
# [<span class="time_write">2021.01.01.</span>]
# [<span>최고예요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkAnmLFXqH/5H5PfCkd5u0vxk6cE4Unlk/wo6lto.jpg" data-platform="kakaomap" data-userid="cogvnm" data-username="앙또" href="javascript:void(0);">앙또</a>]
# [<span class="time_write">2020.12.30.</span>]
# [<span>방문포장. 보온팩포장해줌. 잡내없고 쫀득 고기 질 좋음. 양많은편 사이드 다양. 당일수량만 판매 재방문의사O</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Fd6daabe00819c5d09550d0c4038c512864df93e0%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/7f95a03cfde48912f35186898db3d523302ae5c7?original" data-platform="kakaomap" data-userid="n247ul" data-username="움냠냠" href="javascript:void(0);">움냠냠</a>]
# [<span class="time_write">2020.12.08.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 5
# [<span>역대 먹어본 소곱창 중에서 가장 맛있었음. 곱창 1인분, 대창 1인분 양도 많음  심지어 서비스 찌개 클래스 부터가 다름  다음에 무조건 또 올 듯  직원분이 맛있게 구워주는데 진짜 맛깔나게 구워줌.  * 참고로 곱창만 주문하는 건 안 됨. </span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2F7c54e6d0ded5f8f798c72cd7c49bc5460620763d%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/fb8fb4790c3799cd46dd5f61d2ea19b2983ae434?original" data-platform="kakaomap" data-userid="n0sata" data-username="잭" href="javascript:void(0);">잭</a>]
# [<span class="time_write">2021.03.23.</span>]
# [<span>왜 이렇게 사람이 많은지 잘 모르겠어요 곱창은 곱이 적고 사이즈가 작아요 오히려 파김치와 부추숙주가 좀 메리트 있어요 </span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkFJnygbdD/HELyYz6Mwg4KhjPeGxYwP0/l3vri3.jpg" data-platform="kakaomap" data-userid="8ohind" data-username="JJ" href="javascript:void(0);">JJ</a>]
# [<span class="time_write">2021.03.12.</span>]
# [<span>최고예요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//img1.daumcdn.net/thumb/C80x80.q70/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Fc86f01cc4ed476967b43a2805ad66769c963bf30%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkLaQWn8Wj/a1NSKmBDTY2NEs4kEpatZk/sdms10.jpg" data-platform="kakaomap" data-userid="l92gkr" data-username="예나" href="javascript:void(0);">예나</a>]
# [<span class="time_write">2021.03.02.</span>]
# [<span>맛괜찮고 비싸고 웨이팅 김 웨이팅 빼고 생각해도 가격 대비 좀..</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/df67df1430f5c25d6d90b39a98e0a2485b12461d?original" data-platform="kakaomap" data-userid="131cpth" data-username="ㅈㅅ" href="javascript:void(0);">ㅈㅅ</a>]
# [<span class="time_write">2021.02.04.</span>]
# [<span>좋아요</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/0ddb1e62b226530aaf7f657c831457386a30377b?original" data-platform="kakaomap" data-userid="nknhus" data-username="깜짝맘" href="javascript:void(0);">깜짝맘</a>]
# [<span class="time_write">2021.02.04.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 5
# [<span>보통이에요</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="" data-platform="kakaomap" data-userid="u76s63" data-username="uo" href="javascript:void(0);">uo</a>]
# [<span class="time_write">2021.03.20.</span>]
# [<span>최고예요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="" data-platform="kakaomap" data-userid="10q5pdl" data-username="정무형" href="javascript:void(0);">정무형</a>]
# [<span class="time_write">2020.05.18.</span>]
# [<span>최고예요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# []
# [<span class="time_write">2016.07.24.</span>]
# [<span>커피빈</span>]
# []
# []
# []
# [<span class="time_write">2014.12.05.</span>]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-5b164faab0ae> in <module>
#      41                 print(timestamp)
#      42                 row = {"UserID":user_review,"ItemID":item,"Rating":rating,"Timestamp":timestamp}
# ---> 43                 row = pd.DataFrame(row, index=[i])
#      44                 rating_df = rating_df.append(row,ignore_index=True)
#      45                 time.sleep(1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1704         return mgr
#    1705     except ValueError as e:
# -> 1706         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1707
#    1708
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1700     try:
#    1701         blocks = _form_blocks(arrays, names, axes)
# -> 1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#    1704         return mgr
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     141
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#     145         # Populate known_consolidate, blknos, and blklocs lazily
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     321         for block in self.blocks:
#     322             if block.shape[1:] != mgr_shape[1:]:
# --> 323                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     324         if len(self.items) != tot_items:
#     325             raise AssertionError(
#
# ValueError: Empty data passed with indices specified.

# %%
rating_df
# Out:
#                                                 UserID        ItemID  \
# 0                                            [감사했습니다,]      홍대입구역 이때
# 1                                        [사장님 바뀜 ㅠㅠㅠㅠ]      홍대입구역 이때
# 2    [일단 사람이 별로 없고!! "이때의 라떼"맛있음. 근데 양이 적어서 너무 아쉽 ㅜ...      홍대입구역 이때
# 3                                              [보통이에요]      홍대입구역 이때
# 4                 [친절하고 정성스럽게 만든 커피, 차메뉴가 다양하면 다 좋을 듯]      홍대입구역 이때
# ..                                                 ...           ...
# 147                           [대창이 내스타일! 일반 체인보다 훨씬나음]  왕십리역 왕십리제일곱창
# 148                                  [내 이십 한평생 최대 웨이팅]  왕십리역 왕십리제일곱창
# 149                                            [보통이에요]       혜화역 커피빈
# 150                                             [최고예요]       혜화역 커피빈
# 151                                             [최고예요]       혜화역 커피빈
#
#        Rating      Timestamp
# 0    [5, [점]]  [2021.01.21.]
# 1    [5, [점]]  [2020.11.29.]
# 2    [4, [점]]  [2020.09.14.]
# 3    [3, [점]]  [2020.08.21.]
# 4    [4, [점]]  [2020.08.07.]
# ..        ...            ...
# 147  [5, [점]]  [2017.05.23.]
# 148  [3, [점]]  [2019.04.26.]
# 149  [3, [점]]  [2021.03.20.]
# 150  [5, [점]]  [2020.05.18.]
# 151  [5, [점]]  [2016.07.24.]
#
# [152 rows x 4 columns]
